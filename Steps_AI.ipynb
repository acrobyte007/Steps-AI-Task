# %% [markdown]
# <a href="https://colab.research.google.com/github/acrobyte007/Steps-AI-Task/blob/main/Steps_AI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin, urlparse
import pandas as pd
import concurrent.futures
import threading
import time

class WebCrawler:
    def __init__(self, base_url, max_depth, max_urls=1000, max_workers=10):
        self.base_url = base_url
        self.max_depth = max_depth
        self.max_urls = max_urls  # Adjusted to limit to around 1000 URLs
        self.visited = set()
        self.data = []
        self.lock = threading.Lock()
        self.url_count = 0
        self.max_workers = max_workers

    def crawl(self, url, depth, origin_url=None):
        with self.lock:
            if self.url_count >= self.max_urls or url in self.visited:
                return
            self.visited.add(url)
            self.url_count += 1

        try:
            response = requests.get(url, timeout=10)
            response.raise_for_status()
        except requests.RequestException as e:
            print(f"Failed to retrieve URL: {url} - {e}")
            return

        soup = BeautifulSoup(response.text, 'html.parser')
        self.extract_data(soup, url, origin_url)
        print(f"Finished crawling: {url}")

        if self.url_count < self.max_urls:
            links = self.extract_links(soup, url)
            with concurrent.futures.ThreadPoolExecutor(max_workers=self.max_workers) as executor:
                futures = [executor.submit(self.crawl, link, depth + 1, origin_url=url) for link in links]
                concurrent.futures.wait(futures)

    def extract_data(self, soup, url, origin_url=None):
        headers = soup.find_all(['h1', 'h2', 'h3'])
        for header in headers:
            topic_name = header.get_text(strip=True)
            link = header.find('a')['href'] if header.find('a') else url
            information_text = topic_name

            # Collect text from the following p tags until another header or end of section is found
            for sibling in header.find_next_siblings():
                if sibling.name == 'p':
                    information_text += ' ' + sibling.get_text(strip=True)
                elif sibling.name in ['h1', 'h2', 'h3']:
                    break

            with self.lock:
                self.data.append({
                    'Topic Name': topic_name,
                    'Links': link,
                    'Information and Text': information_text.strip(),
                    'Originating URL': origin_url if origin_url else url  # Add originating URL
                })

    def extract_links(self, soup, base_url):
        links = set()
        for a_tag in soup.find_all('a', href=True):
            href = a_tag['href']
            if not urlparse(href).netloc:
                href = urljoin(base_url, href)
            if href.startswith(self.base_url):
                links.add(href)
        return links

    def start(self):
        self.crawl(self.base_url, 0, origin_url=self.base_url)  # Start with base_url as origin_url
        return self.data

if __name__ == "__main__":
    base_url = "https://docs.nvidia.com/cuda/"
    max_depth = 5

    start_time = time.time()
    crawler = WebCrawler(base_url, max_depth, max_urls=1000)  # Adjusted to crawl around 1000 URLs
    scraped_data = crawler.start()
    end_time = time.time()

    # Convert the scraped data to a DataFrame
    df = pd.DataFrame(scraped_data)

    # Save the DataFrame to a CSV file with URL references
    df.to_csv('nvidia_cuda_docs_info_1000_urls.csv', index=False)

    print(f"Scraped {len(scraped_data)} pages in {end_time - start_time} seconds.")
    print(f"Data has been successfully extracted and saved to 'nvidia_cuda_docs_info_1000_urls.csv'.")
# Out:
# Finished crawling: https://docs.nvidia.com/cuda/
# Finished crawling: https://docs.nvidia.com/cuda/demo-suite/index.html
# Finished crawling: https://docs.nvidia.com/cuda/debugger-api/index.html
# Finished crawling: https://docs.nvidia.com/cuda/#installation-guides
# Finished crawling: https://docs.nvidia.com/cuda/turing-tuning-guide/index.html
# Finished crawling: https://docs.nvidia.com/cuda/ampere-tuning-guide/index.html
# Finished crawling: https://docs.nvidia.com/cuda/cuda-runtime-api/index.html
# Finished crawling: https://docs.nvidia.com/cuda/demo-suite/index.html#notice
# Finished crawling: https://docs.nvidia.com/cuda/ptx-compiler-api/index.html
# Finished crawling: https://docs.nvidia.com/cuda/demo-suite/index.html#oceanfftFinished crawling: https://docs.nvidia.com/cuda/demo-suite/index.html#introduction
#
# Finished crawling: https://docs.nvidia.com/cuda/index.htmlFinished crawling: https://docs.nvidia.com/cuda/demo-suite/index.html#devicequeryFinished crawling: https://docs.nvidia.com/cuda/npp/index.html
# Finished crawling: https://docs.nvidia.com/cuda/demo-suite/index.html#nbody
#
#
# Finished crawling: https://docs.nvidia.com/cuda/demo-suite/index.html#demos
# Finished crawling: https://docs.nvidia.com/cuda/demo-suite/index.html#notices
# Finished crawling: https://docs.nvidia.com/cuda/demo-suite/index.html#busgrind
# Finished crawling: https://docs.nvidia.com/cuda/demo-suite/index.html#trademarks
# Finished crawling: https://docs.nvidia.com/cuda/cuda-runtime-api/structcudaExternalSemaphoreWaitNodeParamsV2.html#structcudaExternalSemaphoreWaitNodeParamsV2Finished crawling: https://docs.nvidia.com/cuda/cuda-runtime-api/structcudaChildGraphNodeParams.html#structcudaChildGraphNodeParams
# Finished crawling: https://docs.nvidia.com/cuda/cuda-runtime-api/structcudaMemcpyNodeParams.html#structcudaMemcpyNodeParams
#
# Finished crawling: https://docs.nvidia.com/cuda/cuda-runtime-api/structcudaPointerAttributes.html#structcudaPointerAttributes
# Finished crawling: https://docs.nvidia.com/cuda/cuda-runtime-api/group__CUDART__D3D9.html#group__CUDART__D3D9
# Finished crawling: https://docs.nvidia.com/cuda/turing-tuning-guide/index.html#occupancy
# Finished crawling: https://docs.nvidia.com/cuda/turing-tuning-guide/index.html#nvidia-turing-compute-architecture
# Finished crawling: https://docs.nvidia.com/cuda/cuda-runtime-api/structcudaLaunchParams.html#structcudaLaunchParams
# Finished crawling: https://docs.nvidia.com/cuda/cuda-runtime-api/group__CUDART__D3D11__DEPRECATED.html#group__CUDART__D3D11__DEPRECATED
# Finished crawling: https://docs.nvidia.com/cuda/turing-tuning-guide/index.html#trademarks
# Finished crawling: https://docs.nvidia.com/cuda/turing-tuning-guide/index.html#application-compatibility
# Finished crawling: https://docs.nvidia.com/cuda/turing-tuning-guide/index.html#turing-tuning
# Finished crawling: https://docs.nvidia.com/cuda/turing-tuning-guide/index.html#tensor-core-operations
# Finished crawling: https://docs.nvidia.com/cuda/cuda-runtime-api/structcudaKernelNodeParams.html#structcudaKernelNodeParams
# Finished crawling: https://docs.nvidia.com/cuda/nvjitlink/index.html
# Finished crawling: https://docs.nvidia.com/cuda/turing-tuning-guide/index.html#fn1
# Finished crawling: https://docs.nvidia.com/cuda/turing-tuning-guide/index.html#cuda-best-practices
# Finished crawling: https://docs.nvidia.com/cuda/turing-tuning-guide/index.html#streaming-multiprocessor
# Finished crawling: https://docs.nvidia.com/cuda/turing-tuning-guide/index.html#integer-arithmetic
# Finished crawling: https://docs.nvidia.com/cuda/nsightee-plugins-install-guide/index.html
# Finished crawling: https://docs.nvidia.com/cuda/index.html#programming-guides
# Finished crawling: https://docs.nvidia.com/cuda/volta-tuning-guide/index.html
# Finished crawling: https://docs.nvidia.com/cuda/maxwell-tuning-guide/index.html
# Finished crawling: https://docs.nvidia.com/cuda/hopper-tuning-guide/index.htmlFinished crawling: https://docs.nvidia.com/cuda/hopper-compatibility-guide/index.html
#
# Finished crawling: https://docs.nvidia.com/cuda/cuda-runtime-api/structcudaDeviceProp.html#structcudaDeviceProp
# Finished crawling: https://docs.nvidia.com/cuda/ampere-tuning-guide/index.html#increased-memory-capacity-and-high-bandwidth-memory
# Finished crawling: https://docs.nvidia.com/cuda/turing-tuning-guide/index.html#notice
# Finished crawling: https://docs.nvidia.com/cuda/ptx-compiler-api/index.html#getting-started
# Finished crawling: https://docs.nvidia.com/cuda/turing-tuning-guide/index.html#fn2
# Finished crawling: https://docs.nvidia.com/cuda/turing-tuning-guide/index.html#unified-shared-memory-l1-texture-cache
# Finished crawling: https://docs.nvidia.com/cuda/turing-tuning-guide/index.html#revision-history
# Finished crawling: https://docs.nvidia.com/cuda/turing-tuning-guide/index.html#instruction-scheduling
# Finished crawling: https://docs.nvidia.com/cuda/turing-tuning-guide/index.html#id1
# Finished crawling: https://docs.nvidia.com/cuda/cuda-runtime-api/structcudaExternalSemaphoreSignalParams__v1.html#structcudaExternalSemaphoreSignalParams__v1
# Finished crawling: https://docs.nvidia.com/cuda/turing-tuning-guide/index.html#turing-tuning-guide
# Finished crawling: https://docs.nvidia.com/cuda/cuda-quick-start-guide/index.html
# Finished crawling: https://docs.nvidia.com/cuda/turing-tuning-guide/index.html#id2Finished crawling: https://docs.nvidia.com/cuda/turing-tuning-guide/index.html#openclFinished crawling: https://docs.nvidia.com/cuda/turing-tuning-guide/contents.html
#
#
# Finished crawling: https://docs.nvidia.com/cuda/turing-tuning-guide/index.html#independent-thread-schedulingFinished crawling: https://docs.nvidia.com/cuda/cuda-runtime-api/group__CUDART__D3D11.html#group__CUDART__D3D11_1gcf0568f3809489723b70f1c5e614d346
#
# Finished crawling: https://docs.nvidia.com/cuda/turing-tuning-guide/index.html#memory-throughput
# Finished crawling: https://docs.nvidia.com/cuda/nvfatbin/index.html
# Finished crawling: https://docs.nvidia.com/cuda/turing-tuning-guide/index.html#notices
# Finished crawling: https://docs.nvidia.com/cuda/demo-suite/contents.html
# Finished crawling: https://docs.nvidia.com/cuda/demo-suite/index.html#bandwidthtest
# Finished crawling: https://docs.nvidia.com/cuda/nvvm-ir-spec/index.html
# Finished crawling: https://docs.nvidia.com/cuda/demo-suite/index.html#vectoradd
# Finished crawling: https://docs.nvidia.com/cuda/demo-suite/index.html#randomfog
# Finished crawling: https://docs.nvidia.com/cuda/demo-suite/index.html#opencl
# Finished crawling: https://docs.nvidia.com/cuda/maxwell-tuning-guide/index.html#fast-shared-memory-atomics
# Finished crawling: https://docs.nvidia.com/cuda/maxwell-tuning-guide/index.html#instruction-throughput
# Finished crawling: https://docs.nvidia.com/cuda/maxwell-tuning-guide/index.html#instruction-latencies
# Finished crawling: https://docs.nvidia.com/cuda/cuda-runtime-api/structcudaResourceDesc.html#structcudaResourceDesc
# Finished crawling: https://docs.nvidia.com/cuda/cuda-runtime-api/group__CUDART__D3D10.html#group__CUDART__D3D10
# Finished crawling: https://docs.nvidia.com/cuda/cuda-runtime-api/group__CUDART__VDPAU.html
# Finished crawling: https://docs.nvidia.com/cuda/maxwell-tuning-guide/index.html#fn2
# Finished crawling: https://docs.nvidia.com/cuda/cuda-runtime-api/group__CUDART__SURFACE__OBJECT.html#group__CUDART__SURFACE__OBJECTFinished crawling: https://docs.nvidia.com/cuda/maxwell-compatibility-guide/
# Finished crawling: https://docs.nvidia.com/cuda/maxwell-tuning-guide/index.html#abstract
#
# Finished crawling: https://docs.nvidia.com/cuda/maxwell-tuning-guide/index.html#instruction-scheduling
# Finished crawling: https://docs.nvidia.com/cuda/nvjitlink/index.html#id1
# Finished crawling: https://docs.nvidia.com/cuda/maxwell-tuning-guide/contents.html
# Finished crawling: https://docs.nvidia.com/cuda/maxwell-tuning-guide/index.html#smm-occupancy
# Finished crawling: https://docs.nvidia.com/cuda/cufft/index.html
# Finished crawling: https://docs.nvidia.com/cuda/npp/introduction.html#introduction_lb_1header_files
# Finished crawling: https://docs.nvidia.com/cuda/cuda-for-tegra-appnote/index.html
# Finished crawling: https://docs.nvidia.com/cuda/ampere-tuning-guide/index.html#nvidia-ampere-gpu-architectureFinished crawling: https://docs.nvidia.com/cuda/ampere-tuning-guide/index.html#notices
# Finished crawling: https://docs.nvidia.com/cuda/nsightee-plugins-install-guide/contents.html
# Finished crawling: https://docs.nvidia.com/cuda/ampere-tuning-guide/index.html#unified-shared-memory-l1-texture-cache
#
# Finished crawling: https://docs.nvidia.com/cuda/ampere-tuning-guide/index.html#improved-tensor-core-operations
# Finished crawling: https://docs.nvidia.com/cuda/cuda-runtime-api/group__CUDART__DEVICE.html#group__CUDART__DEVICE_1gef69dd5c6d0206c2b8d099abac61f217
# Finished crawling: https://docs.nvidia.com/cuda/cuda-runtime-api/group__CUDART__TYPES.html#group__CUDART__TYPES_1gg3f51e3575c2178246db0a94a430e0038e355f04607d824883b4a50662830d591
# Finished crawling: https://docs.nvidia.com/cuda/cuda-runtime-api/structcudaDeviceProp.html#structcudaDeviceProp_13a3f10d2833bdc82ceb370a449aafeec
# Finished crawling: https://docs.nvidia.com/cuda/npp/signal_initialization.html#group__signal__set_1signal_set
# Finished crawling: https://docs.nvidia.com/cuda/cuda-runtime-api/structcudaDeviceProp.html#structcudaDeviceProp_192470653c71f372dbec29bd693d55316Finished crawling: https://docs.nvidia.com/cuda/cuda-runtime-api/structcudaDeviceProp.html#structcudaDeviceProp_17e9a4d56377db11fd9d6b013de9cbf08
#
# Finished crawling: https://docs.nvidia.com/cuda/cuda-runtime-api/structcudaDeviceProp.html#structcudaDeviceProp_13281f4cdba05e2ca43be1caae2bcb29b
# Finished crawling: https://docs.nvidia.com/cuda/cuda-runtime-api/structcudaDeviceProp.html#structcudaDeviceProp_1d170a7ad44ced64478d50fd7b6378b41
# Finished crawling: https://docs.nvidia.com/cuda/nsightee-plugins-install-guide/_images/add_repository.png
# Finished crawling: https://docs.nvidia.com/cuda/cuda-runtime-api/group__CUDART__INTEROP.html#group__CUDART__INTEROP_1g0dd6b5f024dfdcff5c28a08ef9958031
# Finished crawling: https://docs.nvidia.com/cuda/cuda-driver-api/group__CUDA__VDPAU.html#group__CUDA__VDPAU_1ga5e00ff2d3ff2f8b680a69f3bc5cd891
# Finished crawling: https://docs.nvidia.com/cuda/cuda-runtime-api/structcudaDeviceProp.html#structcudaDeviceProp_16f5f5ba8a7dc088392be0d2f8f51faed
# Finished crawling: https://docs.nvidia.com/cuda/cuda-runtime-api/structcudaLaunchParams.html#structcudaLaunchParams_11f780f7a1266c1d820d46b31d025bd0c
# Finished crawling: https://docs.nvidia.com/cuda/cuda-runtime-api/structcudaLaunchMemSyncDomainMap.html
# Finished crawling: https://docs.nvidia.com/cuda/cuda-runtime-api/structcudaLaunchParams.html#structcudaLaunchParams_1ad6b5e617a8c137476babb2ca1b94570
# Finished crawling: https://docs.nvidia.com/cuda/cuda-runtime-api/structcudaHostNodeParams.html#structcudaHostNodeParams
# Finished crawling: https://docs.nvidia.com/cuda/cuda-runtime-api/group__CUDART__EXECUTION__DEPRECATED.html#group__CUDART__EXECUTION__DEPRECATED
# Finished crawling: https://docs.nvidia.com/cuda/cuda-runtime-api/structcudaArraySparseProperties.html#structcudaArraySparseProperties
# Finished crawling: https://docs.nvidia.com/cuda/cuda-runtime-api/structcudaIpcEventHandle__t.html#structcudaIpcEventHandle__t
# Finished crawling: https://docs.nvidia.com/cuda/cuda-runtime-api/structcudaIpcMemHandle__t.html#structcudaIpcMemHandle__t
# Finished crawling: https://docs.nvidia.com/cuda/cuda-runtime-api/structcudaExternalSemaphoreWaitParams.html#structcudaExternalSemaphoreWaitParams
# Finished crawling: https://docs.nvidia.com/cuda/cuda-runtime-api/structcudaMemPoolProps.html#structcudaMemPoolProps
# Finished crawling: https://docs.nvidia.com/cuda/cuda-runtime-api/structcudaAccessPolicyWindow.html#structcudaAccessPolicyWindow_1bbd68021cb5c3cb1928bee0a2941eb24
# Finished crawling: https://docs.nvidia.com/cuda/cuda-runtime-api/group__CUDART__DEVICE.html#group__CUDART__DEVICE_1g45f0345fd7a3697d0766596593920f61
# Finished crawling: https://docs.nvidia.com/cuda/cuda-runtime-api/group__CUDART__TYPES.html#group__CUDART__TYPES_1g7eb25f5413a962faad0956d92bae10d0
# Finished crawling: https://docs.nvidia.com/cuda/cuda-runtime-api/deprecated.html#deprecated__deprecated_1_deprecated000053
# Finished crawling: https://docs.nvidia.com/cuda/cuda-runtime-api/deprecated.html#deprecated__deprecated_1_deprecated000062
# Finished crawling: https://docs.nvidia.com/cuda/cuda-runtime-api/structcudaDeviceProp.html#structcudaDeviceProp_18fe20825e4239ff91a7708c9468a02b5
# Finished crawling: https://docs.nvidia.com/cuda/hopper-tuning-guide/index.html#application-compatibility
# Finished crawling: https://docs.nvidia.com/cuda/hopper-tuning-guide/index.html#streaming-multiprocessor
# Finished crawling: https://docs.nvidia.com/cuda/hopper-tuning-guide/index.html#improved-fp32-throughput
# Finished crawling: https://docs.nvidia.com/cuda/hopper-tuning-guide/index.html#id1
# Finished crawling: https://docs.nvidia.com/cuda/cuda-runtime-api/group__CUDART__DEVICE.html#group__CUDART__DEVICE_1g159587909ffa0791bbe4b40187a4c6bbFinished crawling: https://docs.nvidia.com/cuda/hopper-tuning-guide/index.html#sm-occupancy
#
# Finished crawling: https://docs.nvidia.com/cuda/hopper-compatibility-guide/
# Finished crawling: https://docs.nvidia.com/cuda/hopper-tuning-guide/index.html#nvidia-hopper-tuning-guide
# Finished crawling: https://docs.nvidia.com/cuda/hopper-tuning-guide/index.html#dynamic-programming-instructions
# Finished crawling: https://docs.nvidia.com/cuda/cuda-runtime-api/group__CUDART__TYPES.html#group__CUDART__TYPES_1g61fdef91580735aac38a50eacd4e94f5
# Finished crawling: https://docs.nvidia.com/cuda/cuda-runtime-api/group__CUDART__TYPES.html#group__CUDART__TYPES_1gcd48ae42ffc4c45643c08d007826e790
# Finished crawling: https://docs.nvidia.com/cuda/#programming-guides
# Finished crawling: https://docs.nvidia.com/cuda/#ptx-compiler-api-references
# Finished crawling: https://docs.nvidia.com/cuda/cuda-runtime-api/group__CUDART__TYPES.html#group__CUDART__TYPES_1gg3f51e3575c2178246db0a94a430e0038d3934977826b2e1488dfeb7e0614e776
# Finished crawling: https://docs.nvidia.com/cuda/cuda-runtime-api/group__CUDART__TYPES.html#group__CUDART__TYPES_1gg3f51e3575c2178246db0a94a430e0038938c6e8b96ecde62e3ab5137156f739a
# Finished crawling: https://docs.nvidia.com/cuda/#compiler-sdk
# Finished crawling: https://docs.nvidia.com/cuda/ampere-tuning-guide/index.html#nvidia-ampere-gpu-architecture-tuning
# Finished crawling: https://docs.nvidia.com/cuda/ampere-tuning-guide/index.html#asynchronous-data-copy-from-global-memory-to-shared-memory
# Finished crawling: https://docs.nvidia.com/cuda/ampere-tuning-guide/index.html#fn1
# Finished crawling: https://docs.nvidia.com/cuda/ampere-tuning-guide/index.html#occupancyFinished crawling: https://docs.nvidia.com/cuda/ampere-tuning-guide/index.html#improved-fp32-throughput
# Finished crawling: https://docs.nvidia.com/cuda/ampere-tuning-guide/index.html#id1
#
# Finished crawling: https://docs.nvidia.com/cuda/ampere-tuning-guide/index.html#trademarksFinished crawling: https://docs.nvidia.com/cuda/cuda-runtime-api/group__CUDART__TYPES.html#group__CUDART__TYPES_1g62ab2fcc2eb066702c3694148383749e
#
# Finished crawling: https://docs.nvidia.com/cuda/cuda-runtime-api/group__CUDART__TYPES.html#group__CUDART__TYPES_1gd25056e7a9182a50aa4bc0ada57ca192
# Finished crawling: https://docs.nvidia.com/cuda/ampere-tuning-guide/index.html#cuda-best-practices
# Finished crawling: https://docs.nvidia.com/cuda/cufft/index.html#cufftexecr2c-and-cufftexecd2zFinished crawling: https://docs.nvidia.com/cuda/cuda-runtime-api/group__CUDART__TYPES.html#group__CUDART__TYPES_1g8157cb1b3c077ba222a56779a37d3bd1
#
# Finished crawling: https://docs.nvidia.com/cuda/cuda-runtime-api/group__CUDART__TYPES.html#group__CUDART__TYPES_1gea2f543a9fc0e52fe4ae712920fd1247Finished crawling: https://docs.nvidia.com/cuda/pdf/Ampere_Tuning_Guide.pdf
#
# Finished crawling: https://docs.nvidia.com/cuda/ampere-tuning-guide/index.html#revision-historyFinished crawling: https://docs.nvidia.com/cuda/cuda-runtime-api/group__CUDART__D3D9.html#group__CUDART__D3D9_1gab5efa8a8882a6e0ee99717a434730b0
#
# Finished crawling: https://docs.nvidia.com/cuda/cuda-c-best-practices-guide/#shared-memory
# Finished crawling: https://docs.nvidia.com/cuda/cuda-runtime-api/structcudaLaunchMemSyncDomainMap.html#structcudaLaunchMemSyncDomainMap_1b077dbe4fa7f3525d262b4d6a43a204e
# Finished crawling: https://docs.nvidia.com/cuda/cuda-runtime-api/structcudaExternalMemoryBufferDesc.html#structcudaExternalMemoryBufferDesc
# Finished crawling: https://docs.nvidia.com/cuda/cuda-runtime-api/graphs-thread-safety.html#graphs-thread-safety
# Finished crawling: https://docs.nvidia.com/cuda/cuda-runtime-api/group__CUDART__DRIVER__ENTRY__POINT.html#group__CUDART__DRIVER__ENTRY__POINT
# Finished crawling: https://docs.nvidia.com/cuda/cuda-runtime-api/unioncudaLaunchAttributeValue.html#unioncudaLaunchAttributeValue
# Finished crawling: https://docs.nvidia.com/cuda/cuda-runtime-api/structcudaExternalSemaphoreWaitParams__v1.html#structcudaExternalSemaphoreWaitParams__v1
# Finished crawling: https://docs.nvidia.com/cuda/cuda-runtime-api/version-mixing-rules.html#version-mixing-rules
# Finished crawling: https://docs.nvidia.com/cuda/cuda-runtime-api/modules.html#modules
# Finished crawling: https://docs.nvidia.com/cuda/cuda-runtime-api/group__CUDART__D3D10__DEPRECATED.html#group__CUDART__D3D10__DEPRECATED_1g6ba821f0593cb2163e5980654ccebeed
# Finished crawling: https://docs.nvidia.com/cuda/pdf/Turing_Tuning_Guide.pdf
# Finished crawling: https://docs.nvidia.com/cuda/cuda-runtime-api/group__CUDART__D3D9__DEPRECATED.html#group__CUDART__D3D9__DEPRECATED_1gbf66161e2462ff7ef17cbccef3d6b098
# Finished crawling: https://docs.nvidia.com/cuda/cuda-runtime-api/group__CUDART__D3D9__DEPRECATED.html#group__CUDART__D3D9__DEPRECATED_1g81dd5ad8f5ec63e31a3d32f67dc1ca4c
# Finished crawling: https://docs.nvidia.com/cuda/pdf/Demo_Suite.pdf
# Finished crawling: https://docs.nvidia.com/cuda/npp/signal_initialization.html#c.nppsSet_64f
# Finished crawling: https://docs.nvidia.com/cuda/cuda-runtime-api/group__CUDART__D3D9__DEPRECATED.html#group__CUDART__D3D9__DEPRECATED_1g81b436ab21219ad7192f2d1d1331a365
# Finished crawling: https://docs.nvidia.com/cuda/ptx-compiler-api/index.html#opencl
# Finished crawling: https://docs.nvidia.com/cuda/cuda-installation-guide-microsoft-windows/
# Finished crawling: https://docs.nvidia.com/cuda/ptx-compiler-api/index.html#group__handle_1ga78e3bba9412ef3e505a9a908089c883e
# Finished crawling: https://docs.nvidia.com/cuda/cuda-runtime-api/group__CUDART__TYPES.html#group__CUDART__TYPES
# Finished crawling: https://docs.nvidia.com/cuda/ptx-compiler-api/index.html#query-the-compiled-assembly-image
# Finished crawling: https://docs.nvidia.com/cuda/cuda-quick-start-guide/index.html#linux
# Finished crawling: https://docs.nvidia.com/cuda/cuda-quick-start-guide/index.html#trademarks
# Finished crawling: https://docs.nvidia.com/cuda/cuda-quick-start-guide/index.html#local-installerFinished crawling: https://docs.nvidia.com/cuda/cuda-quick-start-guide/index.html#x86-64-conda
# Finished crawling: https://docs.nvidia.com/cuda/cuda-quick-start-guide/index.html#introduction
#
# Finished crawling: https://docs.nvidia.com/cuda/cuda-quick-start-guide/index.html#local-repo-installation-for-amazon-linux
# Finished crawling: https://docs.nvidia.com/cuda/cuda-quick-start-guide/index.html#fedora
# Finished crawling: https://docs.nvidia.com/cuda/cuda-quick-start-guide/index.html#network-installer
# Finished crawling: https://docs.nvidia.com/cuda/cuda-quick-start-guide/index.html#runfile-installer
# Finished crawling: https://docs.nvidia.com/cuda/cuda-runtime-api/group__CUDART__TYPES.html#group__CUDART__TYPES_1g057e6912c52708b6aa86e79dd83d007c
# Finished crawling: https://docs.nvidia.com/cuda/cuda-runtime-api/group__CUDART__TYPES.html#group__CUDART__TYPES_1gg3f51e3575c2178246db0a94a430e0038bfd977ba87fbe3bd18bf6cb73d4185c2
# Finished crawling: https://docs.nvidia.com/cuda/maxwell-tuning-guide/index.html#revision-historyFinished crawling: https://docs.nvidia.com/cuda/pdf/Maxwell_Tuning_Guide.pdf
#
# Finished crawling: https://docs.nvidia.com/cuda/maxwell-tuning-guide/index.html#notice
# Finished crawling: https://docs.nvidia.com/cuda/maxwell-tuning-guide/index.html#dynamic-parallelism
# Finished crawling: https://docs.nvidia.com/cuda/maxwell-tuning-guide/index.html#cuda-best-practices
# Finished crawling: https://docs.nvidia.com/cuda/maxwell-tuning-guide/index.html#unified-l1-texture-cache
# Finished crawling: https://docs.nvidia.com/cuda/cuda-runtime-api/structcudaExternalSemaphoreWaitParams__v1.html
# Finished crawling: https://docs.nvidia.com/cuda/cuda-runtime-api/structcudaExternalSemaphoreWaitParams.html#structcudaExternalSemaphoreWaitParams_19f05f9250fc28ec345b510a7a7db496d
# Finished crawling: https://docs.nvidia.com/cuda/cuda-driver-api/structCUaccessPolicyWindow__v1.html#structCUaccessPolicyWindow__v1
# Finished crawling: https://docs.nvidia.com/cuda/npp/introduction.html#nppi_conventions_lb_1image_data_parameter_names
# Finished crawling: https://docs.nvidia.com/cuda/hopper-tuning-guide/index.html#nvidia-hopper-gpu-architecture
# Finished crawling: https://docs.nvidia.com/cuda/cuda-runtime-api/structcudaExternalMemoryHandleDesc.html#structcudaExternalMemoryHandleDesc
# Finished crawling: https://docs.nvidia.com/cuda/hopper-tuning-guide/contents.html
# Finished crawling: https://docs.nvidia.com/cuda/cuda-driver-api/group__CUDA__D3D9.html#group__CUDA__D3D9_1ge293c667e76dafaaf47ce64d0bd91c4d
# Finished crawling: https://docs.nvidia.com/cuda/cuda-runtime-api/structcudaMemPoolPtrExportData.html#structcudaMemPoolPtrExportData
# Finished crawling: https://docs.nvidia.com/cuda/cuda-driver-api/group__CUDA__D3D9.html#group__CUDA__D3D9_1g391835e0d3c5a34bdba99840157194bf
# Finished crawling: https://docs.nvidia.com/cuda/cuda-runtime-api/group__CUDART__TYPES.html#group__CUDART__TYPES_1ggb35390be1e170db8671b0abfb57ad3d91f340d33a5242e6aeb3a6a528046f062Finished crawling: https://docs.nvidia.com/cuda/hopper-tuning-guide/index.html#unified-shared-memory-l1-texture-cache
# Finished crawling: https://docs.nvidia.com/cuda/hopper-tuning-guide/index.html#memory-system
# Finished crawling: https://docs.nvidia.com/cuda/hopper-tuning-guide/index.html#fourth-generation-nvlink
# Finished crawling: https://docs.nvidia.com/cuda/cuda-runtime-api/group__CUDART__PEER.html#group__CUDART__PEER
# Finished crawling: https://docs.nvidia.com/cuda/hopper-tuning-guide/index.html#nvidia-hopper-tuning
#
# Finished crawling: https://docs.nvidia.com/cuda/hopper-tuning-guide/index.html#inline-compression
# Finished crawling: https://docs.nvidia.com/cuda/hopper-tuning-guide/index.html#cuda-best-practices
# Finished crawling: https://docs.nvidia.com/cuda/hopper-tuning-guide/index.html#high-bandwidth-memory-hbm3-subsystemFinished crawling: https://docs.nvidia.com/cuda/npp/image_threshold_and_compare_operations.html#group__image__threshold__greater__than__operations_1image_threshold_greater_than_operations
#
# Finished crawling: https://docs.nvidia.com/cuda/cuda-runtime-api/group__CUDART__D3D9__DEPRECATED.html
# Finished crawling: https://docs.nvidia.com/cuda/cuda-runtime-api/group__CUDART__TYPES.html#group__CUDART__TYPES_1gg3f51e3575c2178246db0a94a430e0038e942e4cbbd2bef6e92e293253f055613
# Finished crawling: https://docs.nvidia.com/cuda/cuda-runtime-api/group__CUDART__TYPES.html#group__CUDART__TYPES_1ggd17cc29b28205bbe32ac575eba16c2775e6fe684d912bce0098e86e4463a5e85
# Finished crawling: https://docs.nvidia.com/cuda/cuda-runtime-api/group__CUDART__TYPES.html#group__CUDART__TYPES_1gg3f51e3575c2178246db0a94a430e0038c4673247aee4d1ab8d07871f376e0273
# Finished crawling: https://docs.nvidia.com/cuda/nsightee-plugins-install-guide/index.html#uninstall-plugins-using-eclipse-ide
# Finished crawling: https://docs.nvidia.com/cuda/nsightee-plugins-install-guide/index.html#install-using-scriptFinished crawling: https://docs.nvidia.com/cuda/nsightee-plugins-install-guide/index.html#trademarks
# Finished crawling: https://docs.nvidia.com/cuda/nsightee-plugins-install-guide/index.html#install-plugins-using-eclipse-ide
# Finished crawling: https://docs.nvidia.com/cuda/nsightee-plugins-install-guide/index.html#opencl
#
# Finished crawling: https://docs.nvidia.com/cuda/nsightee-plugins-install-guide/contents.html#contents
# Finished crawling: https://docs.nvidia.com/cuda/nsightee-plugins-install-guide/index.html#notice
# Finished crawling: https://docs.nvidia.com/cuda/cuda-driver-api/group__CUDA__DEVICE.html#group__CUDA__DEVICE_1gdf186e9559d53a5eb18e572d48c1121b
# Finished crawling: https://docs.nvidia.com/cuda/nsightee-plugins-install-guide/index.html#notices
# Finished crawling: https://docs.nvidia.com/cuda/cuda-runtime-api/group__CUDART__D3D10.html
# Finished crawling: https://docs.nvidia.com/cuda/cuda-runtime-api/group__CUDART__DEVICE.html#group__CUDART__DEVICE_1gd9bf5eae6d464de05aa3840df9f5deeb
# Finished crawling: https://docs.nvidia.com/cuda/pascal-compatibility-guide/index.html
# Finished crawling: https://docs.nvidia.com/cuda/maxwell-tuning-guide/contents.html#contents
# Finished crawling: https://docs.nvidia.com/cuda/cuda-runtime-api/group__CUDART__TYPES.html#group__CUDART__TYPES_1gg49e2f8c2c0bd6fe264f2fc970912e5cdc65f6e09e306453928e504124f0400d2
# Finished crawling: https://docs.nvidia.com/cuda/index.html#tools
# Finished crawling: https://docs.nvidia.com/cuda/ptx-writers-guide-to-interoperability/index.html
# Finished crawling: https://docs.nvidia.com/cuda/cuda-runtime-api/structcudaExternalMemoryHandleDesc.html#structcudaExternalMemoryHandleDesc_18d2b65d3b597280eb9be66ee34c7ee52
# Finished crawling: https://docs.nvidia.com/cuda/cuda-runtime-api/structcudaExternalMemoryHandleDesc.html#structcudaExternalMemoryHandleDesc_1fb0a96517b5dfdaa3558d2a871f92385
# Finished crawling: https://docs.nvidia.com/cuda/cuda-runtime-api/structcudaExternalMemoryHandleDesc.html#structcudaExternalMemoryHandleDesc_1362086a22da90ac8fba1ca294e65548e
# Finished crawling: https://docs.nvidia.com/cuda/hopper-tuning-guide/index.html#thread-block-clusters
# Finished crawling: https://docs.nvidia.com/cuda/hopper-tuning-guide/index.html#fn1Failed to retrieve URL: https://docs.nvidia.com/cuda/cuda-occupancy-calculator/CUDA_Occupancy_Calculator.xls - 404 Client Error: Not Found for url: https://docs.nvidia.com/cuda/cuda-occupancy-calculator/CUDA_Occupancy_Calculator.xls/
# Finished crawling: https://docs.nvidia.com/cuda/hopper-tuning-guide/index.html#increased-l2-capacity
# Finished crawling: https://docs.nvidia.com/cuda/hopper-tuning-guide/index.html#opencl
#
# Finished crawling: https://docs.nvidia.com/cuda/hopper-tuning-guide/index.html#occupancy
# Finished crawling: https://docs.nvidia.com/cuda/hopper-tuning-guide/index.html#trademarks
# Finished crawling: https://docs.nvidia.com/cuda/hopper-tuning-guide/index.html#tensor-memory-accelerator
# Finished crawling: https://docs.nvidia.com/cuda/cuda-binary-utilities/index.html
# Finished crawling: https://docs.nvidia.com/cuda/hopper-tuning-guide/index.html#revision-history
# Finished crawling: https://docs.nvidia.com/cuda/cuda-c-best-practices-guide/
# Finished crawling: https://docs.nvidia.com/cuda/hopper-compatibility-guide/index.html#id1
# Finished crawling: https://docs.nvidia.com/cuda/hopper-compatibility-guide/index.html#building-applications-with-hopper-support
# Finished crawling: https://docs.nvidia.com/cuda/hopper-compatibility-guide/index.html#application-compatibility-on-hopper-architecture
# Finished crawling: https://docs.nvidia.com/cuda/cuda-runtime-api/group__CUDART__TYPES.html#group__CUDART__TYPES_1gg62ab2fcc2eb066702c3694148383749e9acb977c3b7bceb6a653e6a718e0f4a0Finished crawling: https://docs.nvidia.com/cuda/cuda-runtime-api/group__CUDART__TYPES.html#group__CUDART__TYPES_1g39b71a7aa040658a7a280fcf31eb4a77
#
# Finished crawling: https://docs.nvidia.com/cuda/cuda-runtime-api/group__CUDART__EVENT.html#group__CUDART__EVENT_1gf4fcb74343aa689f4159791967868446
# Finished crawling: https://docs.nvidia.com/cuda/cuda-runtime-api/group__CUDART__TYPES.html#group__CUDART__TYPES_1gg62ab2fcc2eb066702c3694148383749ed7c20291dcaa0968289cbdc1d1ef9884Finished crawling: https://docs.nvidia.com/cuda/cuda-runtime-api/group__CUDART__EXTRES__INTEROP.html#group__CUDART__EXTRES__INTEROP_1g64f7155c1fc4459a746db31b4aae263b
#
# Finished crawling: https://docs.nvidia.com/cuda/hopper-compatibility-guide/index.html#notices
# Finished crawling: https://docs.nvidia.com/cuda/cuda-runtime-api/structcudaPointerAttributes.html#structcudaPointerAttributes_19edc9782e1ee337072994780fd3b675f
# Finished crawling: https://docs.nvidia.com/cuda/cuda-runtime-api/structcudaPitchedPtr.html
# Finished crawling: https://docs.nvidia.com/cuda/cuda-runtime-api/structcudaDeviceProp.html#structcudaDeviceProp_1e885cf451108cf85dc3b313bce0c9026
# Finished crawling: https://docs.nvidia.com/cuda/maxwell-tuning-guide/index.html#maxwell-tuning
# Finished crawling: https://docs.nvidia.com/cuda/cuda-runtime-api/structcudaMemFreeNodeParams.html
# Finished crawling: https://docs.nvidia.com/cuda/maxwell-tuning-guide/index.html#memory-throughput
# Finished crawling: https://docs.nvidia.com/cuda/cuda-runtime-api/group__CUDART__TYPES.html#group__CUDART__TYPES_1gg4c4b34c054d383b0e9a63ab0ffc9365123b80a6221a6853e918c2816bb76742c
# Finished crawling: https://docs.nvidia.com/cuda/maxwell-tuning-guide/index.html#occupancy
# Finished crawling: https://docs.nvidia.com/cuda/cuda-runtime-api/group__CUDART__TYPES.html#group__CUDART__TYPES_1gg49e2f8c2c0bd6fe264f2fc970912e5cdab8d5fcf5498b163c2a342487b0799c6
# Finished crawling: https://docs.nvidia.com/cuda/cuda-runtime-api/group__CUDART__DEVICE.html#group__CUDART__DEVICE_1gf61f9ae0fe2d93b5b968756684a49460
# Finished crawling: https://docs.nvidia.com/cuda/cuda-runtime-api/group__CUDART__TYPES.html#group__CUDART__TYPES_1gg3f51e3575c2178246db0a94a430e0038265dbf94c45903cd582cfc40f93a176a
# Finished crawling: https://docs.nvidia.com/cuda/hopper-tuning-guide/contents.html#contentsFinished crawling: https://docs.nvidia.com/cuda/cuda-runtime-api/group__CUDART__TYPES.html#group__CUDART__TYPES_1gg13de56a8fe75569530ecc3a3106e9b6dbb20a4b61c559a4e7629fe60ac04b84e
#
# Finished crawling: https://docs.nvidia.com/cuda/cuda-driver-api/group__CUDA__MEM.html#group__CUDA__MEM_1gf1d525918b6c643b99ca8c8e42e36c2e
# Finished crawling: https://docs.nvidia.com/cuda/cuda-runtime-api/group__CUDART__TYPES.html#group__CUDART__TYPES_1gg13de56a8fe75569530ecc3a3106e9b6d30c8466dd99563e4b1a43dd27bf7c743
# Finished crawling: https://docs.nvidia.com/cuda/npp/signal_statistical_functions.html#signal-norms
# Finished crawling: https://docs.nvidia.com/cuda/npp/introduction.html
# Finished crawling: https://docs.nvidia.com/cuda/npp/introduction.html#nppi_conventions_lb
# Finished crawling: https://docs.nvidia.com/cuda/cublas/index.htmlFinished crawling: https://docs.nvidia.com/cuda/npp/image_memory_management.html
#
# Finished crawling: https://docs.nvidia.com/cuda/ampere-tuning-guide/index.html#memory-system
# Finished crawling: https://docs.nvidia.com/cuda/ampere-tuning-guide/index.html#hardware-acceleration-for-split-arrive-wait-barrier
# Finished crawling: https://docs.nvidia.com/cuda/ampere-tuning-guide/index.html#nvidia-ampere-gpu-architecture-tuning-guide
# Finished crawling: https://docs.nvidia.com/cuda/ampere-tuning-guide/index.html#notice
# Finished crawling: https://docs.nvidia.com/cuda/cuda-driver-api/structCUaccessPolicyWindow__v1.html#structCUaccessPolicyWindow__v1_1a0d16743fccf426ddb2186ca777d77fd
# Finished crawling: https://docs.nvidia.com/cuda/cuda-driver-api/group__CUDA__EVENT.html#group__CUDA__EVENT
# Finished crawling: https://docs.nvidia.com/cuda/ampere-tuning-guide/index.html#application-compatibilityFinished crawling: https://docs.nvidia.com/cuda/cuda-driver-api/group__CUDA__ERROR.html#group__CUDA__ERRORFinished crawling: https://docs.nvidia.com/cuda/cuda-driver-api/structCUaccessPolicyWindow__v1.html#structCUaccessPolicyWindow__v1_19f0eaedaf7ce29cf32599ac26b62e1a0
#
# Finished crawling: https://docs.nvidia.com/cuda/ampere-tuning-guide/index.html#opencl
#
# Finished crawling: https://docs.nvidia.com/cuda/ampere-tuning-guide/contents.html
# Finished crawling: https://docs.nvidia.com/cuda/cuda-driver-api/structCUctxCreateParams.html#structCUctxCreateParams
# Finished crawling: https://docs.nvidia.com/cuda/ampere-tuning-guide/index.html#streaming-multiprocessor
# Finished crawling: https://docs.nvidia.com/cuda/ampere-tuning-guide/index.html#third-generation-nvlink
# Finished crawling: https://docs.nvidia.com/cuda/cuda-driver-api/structCUgraphNodeParams.html#structCUgraphNodeParams
# Finished crawling: https://docs.nvidia.com/cuda/cuda-driver-api/structCUDA__ARRAY3D__DESCRIPTOR__v2.html#structCUDA__ARRAY3D__DESCRIPTOR__v2
# Finished crawling: https://docs.nvidia.com/cuda/cuda-driver-api/annotated.html
# Finished crawling: https://docs.nvidia.com/cuda/wsl-user-guide/index.html
# Finished crawling: https://docs.nvidia.com/cuda/cuda-driver-api/structCUDA__KERNEL__NODE__PARAMS__v2.html#structCUDA__KERNEL__NODE__PARAMS__v2
# Finished crawling: https://docs.nvidia.com/cuda/npp/signal_arithmetic_and_logical_operations.html#group__signal__cuberoot_1signal_cuberoot
# Finished crawling: https://docs.nvidia.com/cuda/cuda-runtime-api/group__CUDART__TYPES.html#group__CUDART__TYPES_1gg3f51e3575c2178246db0a94a430e00382ad9b297541678f164fdecc3f719a4d0
# Finished crawling: https://docs.nvidia.com/cuda/cuda-runtime-api/group__CUDART__TYPES.html#group__CUDART__TYPES_1gg3f51e3575c2178246db0a94a430e0038c14f1bebf1cd5d2e44cdfd27e15025e5
# Finished crawling: https://docs.nvidia.com/cuda/cuda-driver-api/group__CUDA__TEXREF__DEPRECATED.html#group__CUDA__TEXREF__DEPRECATED
# Finished crawling: https://docs.nvidia.com/cuda/pdf/Hopper_Tuning_Guide.pdf
# Finished crawling: https://docs.nvidia.com/cuda/cuda-quick-start-guide/index.html#rpm-installerFinished crawling: https://docs.nvidia.com/cuda/hopper-tuning-guide/index.html#notice
#
# Finished crawling: https://docs.nvidia.com/cuda/cuda-quick-start-guide/index.html#fedora-x86-64-run
# Finished crawling: https://docs.nvidia.com/cuda/cuda-quick-start-guide/index.html#debian-x86-64-deb
# Finished crawling: https://docs.nvidia.com/cuda/cuda-quick-start-guide/index.html#local-repo-installation-for-amazon
# Finished crawling: https://docs.nvidia.com/cuda/cuda-quick-start-guide/index.html#linux-x86-64
# Finished crawling: https://docs.nvidia.com/cuda/cuda-quick-start-guide/index.html#debian-x86-64-runFinished crawling: https://docs.nvidia.com/cuda/cuda-quick-start-guide/index.html#windows
#
# Finished crawling: https://docs.nvidia.com/cuda/cuda-runtime-api/group__CUDART__GRAPH.htmlFinished crawling: https://docs.nvidia.com/cuda/cuda-quick-start-guide/index.html#common-installation-instructions-for-amazon-linuxFinished crawling: https://docs.nvidia.com/cuda/cuda-quick-start-guide/index.html#wsl
#
#
# Finished crawling: https://docs.nvidia.com/cuda/demo-suite/contents.html#contents
# Finished crawling: https://docs.nvidia.com/cuda/cuda-runtime-api/structcudaAccessPolicyWindow.html#structcudaAccessPolicyWindow_1bff773e5215e88770cf7eb177c7bfa71
# Finished crawling: https://docs.nvidia.com/cuda/cuda-runtime-api/structcudaGraphExecUpdateResultInfo.html#structcudaGraphExecUpdateResultInfoFinished crawling: https://docs.nvidia.com/cuda/nsightee-plugins-install-guide/_images/NsightEE_plugins_uninstall.png
#
# Finished crawling: https://docs.nvidia.com/cuda/cuda-driver-api/group__CUDA__TYPES.html#group__CUDA__TYPES_1gbf4806140e86865b45fc144941a6ced5
# Finished crawling: https://docs.nvidia.com/cuda/maxwell-tuning-guide/index.html#smm-scheduling
# Finished crawling: https://docs.nvidia.com/cuda/cuda-runtime-api/group__CUDART__TYPES.html#group__CUDART__TYPES_1g4991a8bc9c2356a8da28d093a1da6758
# Finished crawling: https://docs.nvidia.com/cuda/hopper-compatibility-guide/index.html#opencl
# Finished crawling: https://docs.nvidia.com/cuda/cuda-c-programming-guide/index.html#warp-reduce-functions
# Finished crawling: https://docs.nvidia.com/cuda/cuda-c-programming-guide/index.html#async-copy
# Finished crawling: https://docs.nvidia.com/cuda/cuda-c-programming-guide/index.html#wmma
# Finished crawling: https://docs.nvidia.com/cuda/nvjitlink/index.html#group__linking_1ga9957fe993c155c0ef9426bf2466c6434
# Finished crawling: https://docs.nvidia.com/cuda/cuda-runtime-api/group__CUDART__HIGHLEVEL.html#group__CUDART__HIGHLEVEL_1g603b86b20b37823253ff89fe8688ba83
# Finished crawling: https://docs.nvidia.com/cuda/cuda-driver-api/deprecated.html#deprecated__deprecated_1_deprecated000043
# Finished crawling: https://docs.nvidia.com/cuda/cuda-c-programming-guide/index.html#L2_access_intro
# Finished crawling: https://docs.nvidia.com/cuda/cuda-runtime-api/group__CUDART__DEVICE.html#group__CUDART__DEVICE_1gf70468b1bb3a7483d1cc393eb7301f2f
# Finished crawling: https://docs.nvidia.com/cuda/cuda-runtime-api/group__CUDART__TYPES.html#group__CUDART__TYPES_1g26509a522be9d449aa7c8c279612452dFinished crawling: https://docs.nvidia.com/cuda/cuda-runtime-api/group__CUDART__TYPES.html#group__CUDART__TYPES_1g802843d69ca8be35ee050ff66782179e
# Finished crawling: https://docs.nvidia.com/cuda/cuda-runtime-api/group__CUDART__TYPES.html#group__CUDART__TYPES_1g4b4ed6dd17d7c0950e5127138279f86a
#
# Finished crawling: https://docs.nvidia.com/cuda/cuda-runtime-api/group__CUDART__TYPES.html#group__CUDART__TYPES_1g1259f0b7bcff80ba46267c9117f9bb21
# Finished crawling: https://docs.nvidia.com/cuda/cuda-runtime-api/group__CUDART__TYPES.html#group__CUDART__TYPES_1g8cb5bdac32ad53c423992a125b3f9a66
# Finished crawling: https://docs.nvidia.com/cuda/cuda-runtime-api/group__CUDART__TYPES.html#group__CUDART__TYPES_1g6820071ffa1300699897eab8d319e4d9
# Finished crawling: https://docs.nvidia.com/cuda/cuda-c-programming-guide/index.html#physical-memory-type-compression
# Finished crawling: https://docs.nvidia.com/cuda/cuda-runtime-api/structcudaDeviceProp.html#structcudaDeviceProp_1b4047e5e22082b1aefeac3b9ef39d0be
# Finished crawling: https://docs.nvidia.com/cuda/cuda-runtime-api/structcudaDeviceProp.html#structcudaDeviceProp_1f7230860be3e37047c7ce5d32542b54b
# Finished crawling: https://docs.nvidia.com/cuda/cuda-runtime-api/structcudaDeviceProp.html#structcudaDeviceProp_17e123c52deb1c940d9e0dc4bbac64a76
# Finished crawling: https://docs.nvidia.com/cuda/cuda-runtime-api/structcudaDeviceProp.html#structcudaDeviceProp_16cf36809ff5ed6b8aa836177d0292200
# Finished crawling: https://docs.nvidia.com/cuda/cuda-runtime-api/group__CUDART__MEMORY__POOLS.html#group__CUDART__MEMORY__POOLS_1g0faf526bcfffd835aa95a4514fb2f7d5
# Finished crawling: https://docs.nvidia.com/cuda/cuda-runtime-api/deprecated.html#deprecated__deprecated_1_deprecated000057
# Finished crawling: https://docs.nvidia.com/cuda/cuda-runtime-api/group__CUDART__TYPES.html#group__CUDART__TYPES_1gc50dd5d226be88b768de22e849c9bf7a
# Finished crawling: https://docs.nvidia.com/cuda/cuda-runtime-api/group__CUDART__GRAPH.html#group__CUDART__GRAPH_1g131318ac4e85b212b6ce91c3164f9e41
# Finished crawling: https://docs.nvidia.com/cuda/maxwell-compatibility-guide/#notice
# Finished crawling: https://docs.nvidia.com/cuda/cuda-driver-api/group__CUDA__TYPES.html#group__CUDA__TYPES_1g183f7b0d8ad008ea2a5fd552537ace4eFinished crawling: https://docs.nvidia.com/cuda/cuda-driver-api/group__CUDA__TYPES.html#group__CUDA__TYPES_1ggc925457ee7128d6251071f6ff76088878ed20ebe21592443f61ecc06d61f32f4
#
# Finished crawling: https://docs.nvidia.com/cuda/cuda-runtime-api/group__CUDART__TYPES.html#group__CUDART__TYPES_1gg49e2f8c2c0bd6fe264f2fc970912e5cdb496a68470a711a91b1decaf3722b876Finished crawling: https://docs.nvidia.com/cuda/maxwell-compatibility-guide/#about-this-document
#
# Finished crawling: https://docs.nvidia.com/cuda/cuda-runtime-api/group__CUDART__TYPES.html#group__CUDART__TYPES_1g4808e47eba73eb94622ec70a9f9b91ff
# Finished crawling: https://docs.nvidia.com/cuda/cuda-runtime-api/group__CUDART__TYPES.html#group__CUDART__TYPES_1gg49e2f8c2c0bd6fe264f2fc970912e5cdb08e379a7a038dc8134914702c223f69
# Finished crawling: https://docs.nvidia.com/cuda/cuda-runtime-api/deprecated.html#deprecated__deprecated_1_deprecated000021
# Finished crawling: https://docs.nvidia.com/cuda/cuda-runtime-api/group__CUDART__TYPES.html#group__CUDART__TYPES_1gaf8b3ba752727d996074a71ee997ce68
# Finished crawling: https://docs.nvidia.com/cuda/cuda-runtime-api/group__CUDART__TYPES.html#group__CUDART__TYPES_1g38818d647e61a5d15fb8012fe54c2d24
# Finished crawling: https://docs.nvidia.com/cuda/cuda-runtime-api/group__CUDART__TYPES.html#group__CUDART__TYPES_1gg49e2f8c2c0bd6fe264f2fc970912e5cdc2a1bce21302fee6da652e0afd92dfc0
# Finished crawling: https://docs.nvidia.com/cuda/cuda-runtime-api/group__CUDART__TYPES.html#group__CUDART__TYPES_1gg49e2f8c2c0bd6fe264f2fc970912e5cda22e3d29bc779b832338003a58c11771
# Finished crawling: https://docs.nvidia.com/cuda/cuda-runtime-api/group__CUDART__TYPES.html#group__CUDART__TYPES_1gf01347c3dafebf07e1a0b4321a030a63
# Finished crawling: https://docs.nvidia.com/cuda/cuda-runtime-api/group__CUDART__TYPES.html#group__CUDART__TYPES_1g6f8811acffcc133b5e4a50de6646d18e
# Finished crawling: https://docs.nvidia.com/cuda/cuda-runtime-api/deprecated.html#deprecated__deprecated_1_deprecated000025
# Finished crawling: https://docs.nvidia.com/cuda/ptx-compiler-api/index.html#destroy-the-compiler
# Finished crawling: https://docs.nvidia.com/cuda/cuda-runtime-api/deprecated.html#deprecated__deprecated_1_deprecated000018
# Finished crawling: https://docs.nvidia.com/cuda/cuda-runtime-api/group__CUDART__TYPES.html#group__CUDART__TYPES_1g6ac3a22cc596d09ac07cdafb8a4638cf
# Finished crawling: https://docs.nvidia.com/cuda/cuda-driver-api/group__CUDA__TYPES.html#group__CUDA__TYPES_1ggb257b534afdb704b6ebdb99c16a5b292d4e126a89b57ebf4a213ee1774ed103f
# Finished crawling: https://docs.nvidia.com/cuda/cuda-runtime-api/group__CUDART__TYPES.html#group__CUDART__TYPES_1g1b03ad14fc0ab86f8b033837f5562d8a
# Finished crawling: https://docs.nvidia.com/cuda/cuda-runtime-api/group__CUDART__D3D9__DEPRECATED.html#group__CUDART__D3D9__DEPRECATED_1g37e568318e2f937fe06020a675497b1e
# Finished crawling: https://docs.nvidia.com/cuda/pdf/Nsight_Eclipse_Plugins_Installation_Guide.pdf
# Finished crawling: https://docs.nvidia.com/cuda/ptx-compiler-api/index.html#_CPPv4N18nvPTXCompileResult43NVPTXCOMPILE_ERROR_UNSUPPORTED_DEVSIDE_SYNCE
# Finished crawling: https://docs.nvidia.com/cuda/ptx-compiler-api/index.html#basic-usage
# Finished crawling: https://docs.nvidia.com/cuda/ptx-compiler-api/index.html#_CPPv4N18nvPTXCompileResult32NVPTXCOMPILE_ERROR_OUT_OF_MEMORYE
# Finished crawling: https://docs.nvidia.com/cuda/cuda-runtime-api/group__CUDART__TYPES.html#group__CUDART__TYPES_1g79a2bf6a3a2aa9011a96dc17d476faf7
# Finished crawling: https://docs.nvidia.com/cuda/cuda-runtime-api/group__CUDART__MEMORY.html#group__CUDART__MEMORY
# Finished crawling: https://docs.nvidia.com/cuda/nvjitlink/index.html#group__linking_1ga04b722539d968953cb5cc70488e3f47a
# Finished crawling: https://docs.nvidia.com/cuda/ptx-writers-guide-to-interoperability/index.html#trademarks
# Finished crawling: https://docs.nvidia.com/cuda/ptx-writers-guide-to-interoperability/index.html#bit-fields-bitfields3
# Finished crawling: https://docs.nvidia.com/cuda/ptx-writers-guide-to-interoperability/index.html#aggregates-and-unions
# Finished crawling: https://docs.nvidia.com/cuda/cuda-quick-start-guide/index.html#pip-wheels-linux
# Finished crawling: https://docs.nvidia.com/cuda/cuda-quick-start-guide/index.html#suse-x86-64-rpm
# Finished crawling: https://docs.nvidia.com/cuda/nvjitlink/index.html#_CPPv421nvJitLinkGetLinkedPtx15nvJitLinkHandlePc
# Finished crawling: https://docs.nvidia.com/cuda/cuda-runtime-api/structcudaExternalSemaphoreSignalNodeParams.html#structcudaExternalSemaphoreSignalNodeParams
# Finished crawling: https://docs.nvidia.com/cuda/nvjitlink/index.html#_CPPv419nvJitLinkGetInfoLog15nvJitLinkHandlePcFinished crawling: https://docs.nvidia.com/cuda/cuda-runtime-api/structcudaLaunchMemSyncDomainMap.html#structcudaLaunchMemSyncDomainMap
#
# Finished crawling: https://docs.nvidia.com/cuda/nvjitlink/index.html#_CPPv417nvJitLinkComplete15nvJitLinkHandle
# Finished crawling: https://docs.nvidia.com/cuda/cuda-runtime-api/driver-vs-runtime-api.html#driver-vs-runtime-api
# Finished crawling: https://docs.nvidia.com/cuda/cuda-quick-start-guide/index.html#prepare-amazon-linux-2023
# Finished crawling: https://docs.nvidia.com/cuda/cuda-quick-start-guide/index.html#sles-x86-64-rpm
# Finished crawling: https://docs.nvidia.com/cuda/cuda-runtime-api/structcudaExternalSemaphoreWaitNodeParams.html#structcudaExternalSemaphoreWaitNodeParams
# Finished crawling: https://docs.nvidia.com/cuda/cuda-runtime-api/structcudaPitchedPtr.html#structcudaPitchedPtr
# Finished crawling: https://docs.nvidia.com/cuda/cuda-driver-api/structCUDA__ARRAY3D__DESCRIPTOR__v2.html
# Finished crawling: https://docs.nvidia.com/cuda/cuda-runtime-api/group__CUDART__TYPES.html#group__CUDART__TYPES_1gf8bc7ab93d638c5835e5289ac7d683c4
# Finished crawling: https://docs.nvidia.com/cuda/cuda-c-programming-guide/
# Finished crawling: https://docs.nvidia.com/cuda/maxwell-tuning-guide/index.html#fn1Finished crawling: https://docs.nvidia.com/cuda/maxwell-tuning-guide/index.html#smm
#
# Finished crawling: https://docs.nvidia.com/cuda/maxwell-tuning-guide/index.html#smm-latencies
# Finished crawling: https://docs.nvidia.com/cuda/maxwell-tuning-guide/index.html#id3
# Finished crawling: https://docs.nvidia.com/cuda/maxwell-tuning-guide/index.html#shared-memory-bandwidth
# Finished crawling: https://docs.nvidia.com/cuda/maxwell-tuning-guide/index.html#id2
# Finished crawling: https://docs.nvidia.com/cuda/maxwell-tuning-guide/index.html#shared-memory
# Finished crawling: https://docs.nvidia.com/cuda/maxwell-tuning-guide/index.html#trademarks
# Finished crawling: https://docs.nvidia.com/cuda/maxwell-tuning-guide/index.html#opencl
# Finished crawling: https://docs.nvidia.com/cuda/maxwell-tuning-guide/index.html#application-compatibility
# Finished crawling: https://docs.nvidia.com/cuda/cuda-runtime-api/structcudaChannelFormatDesc.html#structcudaChannelFormatDesc_170dede802100e2acd9f334326e9d7926
# Finished crawling: https://docs.nvidia.com/cuda/cuda-runtime-api/api-sync-behavior.html#api-sync-behavior__memcpy-sync
# Finished crawling: https://docs.nvidia.com/cuda/cuda-runtime-api/group__CUDART__EVENT.html#group__CUDART__EVENT
# Finished crawling: https://docs.nvidia.com/cuda/cuda-runtime-api/deprecated.html#deprecated
# Finished crawling: https://docs.nvidia.com/cuda/cuda-runtime-api/structcudaExternalMemoryHandleDesc.html#structcudaExternalMemoryHandleDesc_14ebe637addc306d6033e9ea6e032374d
# Finished crawling: https://docs.nvidia.com/cuda/cuda-runtime-api/group__CUDART__HIGHLEVEL.html#group__CUDART__HIGHLEVEL_1gd00b41ade29161aafbf6ff8aee3d6eb5
# Finished crawling: https://docs.nvidia.com/cuda/npp/image_linear_transforms.htmlFinished crawling: https://docs.nvidia.com/cuda/cuda-runtime-api/group__CUDART__TYPES.html#group__CUDART__TYPES_1gg3f51e3575c2178246db0a94a430e0038b1f959cb68eedda7fbbd28403e67fa33
#
# Finished crawling: https://docs.nvidia.com/cuda/cuda-binary-utilities/index.html#noticeFinished crawling: https://docs.nvidia.com/cuda/cuda-runtime-api/group__CUDART__TYPES.html#group__CUDART__TYPES_1gg3f51e3575c2178246db0a94a430e003872ce39cee8ef48a83b0191b2e33d2630
#
# Finished crawling: https://docs.nvidia.com/cuda/cuda-runtime-api/group__CUDART__D3D11__DEPRECATED.html#group__CUDART__D3D11__DEPRECATED_1g533524c773e7ca4ef57c0698b157d670
# Finished crawling: https://docs.nvidia.com/cuda/cuda-runtime-api/group__CUDART__HIGHLEVEL.html#group__CUDART__HIGHLEVEL_1gef663acab61362749507747e30fb210d
# Finished crawling: https://docs.nvidia.com/cuda/cuda-runtime-api/structcudaExternalSemaphoreSignalNodeParamsV2.html#structcudaExternalSemaphoreSignalNodeParamsV2
# Finished crawling: https://docs.nvidia.com/cuda/npp/image_memory_management.html#c.nppiMalloc_32fc_C4
# Finished crawling: https://docs.nvidia.com/cuda/cuda-runtime-api/stream-sync-behavior.html#stream-sync-behaviorFinished crawling: https://docs.nvidia.com/cuda/npp/image_memory_management.html#c.nppiMalloc_16sc_C4Finished crawling: https://docs.nvidia.com/cuda/cuda-runtime-api/group__CUDART__MEMORY.html#group__CUDART__MEMORY_1g9509226164aaa58baf0c5b8ed165df58
#
#
# ...
# Finished crawling: https://docs.nvidia.com/cuda/npp/image_memory_management.html#c.nppiMalloc_32fc_C2
# Finished crawling: https://docs.nvidia.com/cuda/npp/image_memory_management.html#c.nppiMalloc_16u_C2
# Finished crawling: https://docs.nvidia.com/cuda/cuda-driver-api/group__CUDA__GL__DEPRECATED.html#group__CUDA__GL__DEPRECATED_1gaeba53543521eec9ad519bf3fa5574c0
# Finished crawling: https://docs.nvidia.com/cuda/cuda-driver-api/group__CUDA__D3D9__DEPRECATED.html#group__CUDA__D3D9__DEPRECATED_1g84dbbbfc3cbb9260e22fea8f632c40ac
# Finished crawling: https://docs.nvidia.com/cuda/cuda-driver-api/group__CUDA__D3D9__DEPRECATED.html#group__CUDA__D3D9__DEPRECATED_1gdf64c251f6fdc73869b7ccdf34befb1c
# Finished crawling: https://docs.nvidia.com/cuda/nvjitlink/index.html#_CPPv416nvJitLinkVersionPjPj
# Finished crawling: https://docs.nvidia.com/cuda/cuda-runtime-api/group__CUDART__TYPES.html#group__CUDART__TYPES_1gg3f51e3575c2178246db0a94a430e0038ce7993a88ecf2c57b8102d55d997a18c
# Finished crawling: https://docs.nvidia.com/cuda/cuda-driver-api/group__CUDA__UNIFIED.html#group__CUDA__UNIFIED_1g27608c857a9254789c13f3e3b72029e2
# Finished crawling: https://docs.nvidia.com/cuda/npp/image_memory_management.html#c.nppiMalloc_16u_C3
# Finished crawling: https://docs.nvidia.com/cuda/npp/image_memory_management.html#c.nppiMalloc_32f_C1
# Finished crawling: https://docs.nvidia.com/cuda/cufft/index.html#c.cufftXtMemcpy
# Finished crawling: https://docs.nvidia.com/cuda/cuda-runtime-api/group__CUDART__TYPES.html#group__CUDART__TYPES_1gg18fa99055ee694244a270e4d5101e95b1a03d03a676ea8ec51b9b1e193617568
# Finished crawling: https://docs.nvidia.com/cuda/cuda-runtime-api/structcudaDeviceProp.html#structcudaDeviceProp_16011fd7e13a77d58fbbd4a5ba1801fbf
# Finished crawling: https://docs.nvidia.com/cuda/npp/image_memory_management.html#c.nppiMalloc_32fc_C3
# Finished crawling: https://docs.nvidia.com/cuda/npp/image_memory_management.html#c.nppiMalloc_8u_C1
# Finished crawling: https://docs.nvidia.com/cuda/cufft/index.html#fft-types
# Finished crawling: https://docs.nvidia.com/cuda/npp/nppdefs.html#c.Npp16u
# Finished crawling: https://docs.nvidia.com/cuda/cuda-runtime-api/group__CUDART__TYPES.html#group__CUDART__TYPES_1gf599e5b8b829ce7db0f5216928f6ecb6
# Finished crawling: https://docs.nvidia.com/cuda/cuda-driver-api/group__CUDA__TYPES.html#group__CUDA__TYPES_1gg578d7cf687ce20f7e99468e8c14e22de07a4ae30f555b208dcb2065320c9e2e1
# Finished crawling: https://docs.nvidia.com/cuda/cuda-driver-api/group__CUDA__TYPES.html#group__CUDA__TYPES_1gge12b8a782bebe21b1ac0091bf9f4e2a3ad1ddf0aacf815961d7016020ca5201d
# Finished crawling: https://docs.nvidia.com/cuda/ptx-compiler-api/index.html#compilation-options
# Finished crawling: https://docs.nvidia.com/cuda/ptx-compiler-api/contents.html
# Finished crawling: https://docs.nvidia.com/cuda/cufft/index.html#bfloat16-precision-cufft-transforms
# Finished crawling: https://docs.nvidia.com/cuda/cuda-driver-api/group__CUDA__MEM.html#group__CUDA__MEM_1g5f26aaf5582ade791e5688727a178d78
# Finished crawling: https://docs.nvidia.com/cuda/cuda-driver-api/group__CUDA__D3D10__DEPRECATED.html#group__CUDA__D3D10__DEPRECATED_1g7795faffd5e58e04f277263d310278fe
# Finished crawling: https://docs.nvidia.com/cuda/npp/signal_filtering_functions.html
# Finished crawling: https://docs.nvidia.com/cuda/cuda-runtime-api/group__CUDART__MEMORY.html#group__CUDART__MEMORY_1gbfde4ace9ff4823f4ac45e5c6bdcd2ee
# Finished crawling: https://docs.nvidia.com/cuda/cuda-runtime-api/group__CUDART__D3D9__DEPRECATED.html#group__CUDART__D3D9__DEPRECATED_1gcdebbc14eb83032da31bd75503cddfea
# Finished crawling: https://docs.nvidia.com/cuda/ptx-compiler-api/index.html#example-simple-vector-addition
# Finished crawling: https://docs.nvidia.com/cuda/ptx-compiler-api/index.html#group__compilation_1ga026bf92499c9c0e362b4b899b1550f6a
# Finished crawling: https://docs.nvidia.com/cuda/cuda-driver-api/group__CUDA__TYPES.html#group__CUDA__TYPES_1gg5527fa8030d5cabedc781a04dbd1997d70d0672317491b398f27bac394b9f66d
# Finished crawling: https://docs.nvidia.com/cuda/cuda-driver-api/group__CUDA__EXEC__DEPRECATED.html#group__CUDA__EXEC__DEPRECATED_1g24e5ceee66d1a84609b74e77672638b6
# Finished crawling: https://docs.nvidia.com/cuda/cuda-runtime-api/group__CUDART__D3D9__DEPRECATED.html#group__CUDART__D3D9__DEPRECATED_1g77fb48ace0d2da465b6f4bcc00ef750b
# Finished crawling: https://docs.nvidia.com/cuda/npp/signal_initialization.html#c.nppsZero_32sc
# Finished crawling: https://docs.nvidia.com/cuda/wsl-user-guide/index.html#containers-vs-wsl-2
# Finished crawling: https://docs.nvidia.com/cuda/cuda-runtime-api/deprecated.html#deprecated__deprecated_1_deprecated000026
# Finished crawling: https://docs.nvidia.com/cuda/ptx-compiler-api/index.html#_CPPv423nvPTXCompilerGetInfoLog19nvPTXCompilerHandlePc
# Finished crawling: https://docs.nvidia.com/cuda/npp/signal_initialization.html#c.nppsCopy_8u_Ctx
# Finished crawling: https://docs.nvidia.com/cuda/wsl-user-guide/index.html#features-not-yet-supported
# Finished crawling: https://docs.nvidia.com/cuda/cuda-runtime-api/structcudaPitchedPtr.html#structcudaPitchedPtr_1412fba6b15962413c9f586c3a1ecb69b
# Finished crawling: https://docs.nvidia.com/cuda/npp/signal_initialization.html#c.nppsZero_32s
# Finished crawling: https://docs.nvidia.com/cuda/cuda-driver-api/group__CUDA__TYPES.html#group__CUDA__TYPES_1gc72514a94dacc85ed0617f979211079c
# Finished crawling: https://docs.nvidia.com/cuda/cuda-runtime-api/deprecated.html#deprecated__deprecated_1_deprecated000022
# Finished crawling: https://docs.nvidia.com/cuda/cuda-runtime-api/group__CUDART____VERSION.html#group__CUDART____VERSION
# Finished crawling: https://docs.nvidia.com/cuda/nvjitlink/index.html#_CPPv4N18nvJitLinkInputType22NVJITLINK_INPUT_FATBINE
# Finished crawling: https://docs.nvidia.com/cuda/cuda-runtime-api/group__CUDART__OPENGL.html
# Finished crawling: https://docs.nvidia.com/cuda/cuda-runtime-api/group__CUDART__EXECUTION.html#group__CUDART__EXECUTION
# Finished crawling: https://docs.nvidia.com/cuda/npp/signal_initialization.html#signal-initialization-functions
# Finished crawling: https://docs.nvidia.com/cuda/cuda-runtime-api/structcudaChildGraphNodeParams.html#structcudaChildGraphNodeParams_1aa94d47a2ea6736803715f69fded063d
# Finished crawling: https://docs.nvidia.com/cuda/wsl-user-guide/index.html#cuda-support-for-wsl-2
# Finished crawling: https://docs.nvidia.com/cuda/cuda-runtime-api/group__CUDART__EGL.html#group__CUDART__EGL
# Finished crawling: https://docs.nvidia.com/cuda/cuda-runtime-api/structcudaExternalMemoryMipmappedArrayDesc.html#structcudaExternalMemoryMipmappedArrayDesc_142333e3049cc4a40213b086be45927e1
# Finished crawling: https://docs.nvidia.com/cuda/cuda-driver-api/group__CUDA__D3D10__DEPRECATED.html#group__CUDA__D3D10__DEPRECATED_1g476a6f370797a72d0238898e5d3e93ce
# Finished crawling: https://docs.nvidia.com/cuda/cuda-runtime-api/structcudaMemPoolProps.html#structcudaMemPoolProps_193dcf13a9ddc7114384e78f66c9489df
# Finished crawling: https://docs.nvidia.com/cuda/wsl-user-guide/index.html#traditional-virtual-machines-vs-wsl-2
# Finished crawling: https://docs.nvidia.com/cuda/wsl-user-guide/index.html#checking-wsl-kernel-version
# Finished crawling: https://docs.nvidia.com/cuda/npp/image_data_exchange_and_initialization.html#group__image__set_1ga217e8dacb892f5f24ab1789a0fdae0b2
# Finished crawling: https://docs.nvidia.com/cuda/cuda-runtime-api/structcudaExternalMemoryMipmappedArrayDesc.html#structcudaExternalMemoryMipmappedArrayDesc
# Finished crawling: https://docs.nvidia.com/cuda/cuda-runtime-api/group__CUDART__EXTRES__INTEROP.html#group__CUDART__EXTRES__INTEROP_1g091a4383a816eb7127aa5c7a7c32cef7
# Finished crawling: https://docs.nvidia.com/cuda/cuda-driver-api/group__CUDA__TYPES.html#group__CUDA__TYPES_1g466d4731f270b66441a355ddb2c84777
# Finished crawling: https://docs.nvidia.com/cuda/cuda-runtime-api/group__CUDART__PROFILER.html#group__CUDART__PROFILER
# Finished crawling: https://docs.nvidia.com/cuda/debugger-api/structCUDBGEvent_1_1cases__st_1_1contextPush__st.html
# Finished crawling: https://docs.nvidia.com/cuda/cuda-runtime-api/group__CUDART__EXTRES__INTEROP.html#group__CUDART__EXTRES__INTEROP_1g819b1377357312acb3135eb9393a0bee
# Finished crawling: https://docs.nvidia.com/cuda/volta-tuning-guide/index.html#nvidia-volta-compute-architecture
# Finished crawling: https://docs.nvidia.com/cuda/wsl-user-guide/index.html#notice
# Finished crawling: https://docs.nvidia.com/cuda/cuda-driver-api/group__CUDA__TYPES.html#group__CUDA__TYPES_1gg9f889e28a45a295b5c8ce13aa05f6cd462aebfe6432ade3feb32f1a409027852
# Finished crawling: https://docs.nvidia.com/cuda/cuda-runtime-api/group__CUDART__D3D9__DEPRECATED.html#group__CUDART__D3D9__DEPRECATED_1gg77fb48ace0d2da465b6f4bcc00ef750b231d4d21c0022f27e2bab622cdfce74f
# Finished crawling: https://docs.nvidia.com/cuda/cuda-runtime-api/group__CUDART__TYPES.html#group__CUDART__TYPES_1ggb35390be1e170db8671b0abfb57ad3d9c114b87111d1cf5315e8370bfab80fe4
# Finished crawling: https://docs.nvidia.com/cuda/debugger-api/modules.html#modules
# Finished crawling: https://docs.nvidia.com/cuda/cuda-quick-start-guide/index.html#pip-wheels-windows
# Finished crawling: https://docs.nvidia.com/cuda/npp/image_memory_management.html#c.nppiFree
# Finished crawling: https://docs.nvidia.com/cuda/debugger-api/group__BP.html#group__BP
# Finished crawling: https://docs.nvidia.com/cuda/cuda-driver-api/group__CUDA__GREEN__CONTEXTS.html#group__CUDA__GREEN__CONTEXTS_1ga6da4f9959fd48d1f1a5cbedbec54e65
# Finished crawling: https://docs.nvidia.com/cuda/npp/image_threshold_and_compare_operations.html#c.nppiThreshold_Val_32f_C1IR_Ctx
# Finished crawling: https://docs.nvidia.com/cuda/cuda-runtime-api/group__CUDART__MEMORY__POOLS.html
# Finished crawling: https://docs.nvidia.com/cuda/cuda-runtime-api/structcudaDeviceProp.html#structcudaDeviceProp_11468730923ddf5a68ecc9bb42053c1c9
# Finished crawling: https://docs.nvidia.com/cuda/cuda-runtime-api/group__CUDART__THREAD__DEPRECATED.html#group__CUDART__THREAD__DEPRECATED_1g6c0354cf06af1854f3d267e142bc6629
# Finished crawling: https://docs.nvidia.com/cuda/npp/image_threshold_and_compare_operations.html#c.nppiThreshold_LTVal_8u_C1R
# Finished crawling: https://docs.nvidia.com/cuda/cuda-runtime-api/group__CUDART__TYPES.html
# Finished crawling: https://docs.nvidia.com/cuda/cuda-quick-start-guide/index.html#network-repo-installation-for-amazon
# Finished crawling: https://docs.nvidia.com/cuda/cuda-runtime-api/structcudaEventRecordNodeParams.html#structcudaEventRecordNodeParams_13e8bdefbef62f1b50714983204a6cdb2
# Finished crawling: https://docs.nvidia.com/cuda/volta-tuning-guide/index.html#integer-arithmetic
# Finished crawling: https://docs.nvidia.com/cuda/npp/image_linear_transforms.html#image-linear-transforms-functions
# Finished crawling: https://docs.nvidia.com/cuda/npp/nppdefs.html#c.Npp8s
# Finished crawling: https://docs.nvidia.com/cuda/cuda-runtime-api/structcudaDeviceProp.html#structcudaDeviceProp_1500248658a996f51752e1ab1769f8a88
# Finished crawling: https://docs.nvidia.com/cuda/debugger-api/structCUDBGEventCallbackData.html#structCUDBGEventCallbackData
# Finished crawling: https://docs.nvidia.com/cuda/cuda-driver-api/group__CUDA__GRAPH.html#group__CUDA__GRAPH
# Finished crawling: https://docs.nvidia.com/cuda/cuda-quick-start-guide/index.html#ubuntu
# Finished crawling: https://docs.nvidia.com/cuda/cuda-runtime-api/group__CUDART__D3D9__DEPRECATED.html#group__CUDART__D3D9__DEPRECATED_1ge9a5aef299347c403cd8f96855d61fb4
# Finished crawling: https://docs.nvidia.com/cuda/ptx-writers-guide-to-interoperability/index.html#bit-fields-bitfields6
# Finished crawling: https://docs.nvidia.com/cuda/volta-tuning-guide/index.html#nvlink-interconnect
# Finished crawling: https://docs.nvidia.com/cuda/npp/signal_initialization.html#c.nppsCopy_32fc
# Finished crawling: https://docs.nvidia.com/cuda/pdf/Volta_Tuning_Guide.pdf
# Finished crawling: https://docs.nvidia.com/cuda/cuda-runtime-api/structcudaExternalSemaphoreSignalParams.html#structcudaExternalSemaphoreSignalParams_1822d9eb7c19587ca89dd56d68c6b7867
# Finished crawling: https://docs.nvidia.com/cuda/npp/nppdefs.html#c.NppStatus
# Finished crawling: https://docs.nvidia.com/cuda/cufft/index.html#streamed-cufft-transforms
# Finished crawling: https://docs.nvidia.com/cuda/npp/nppdefs.html#c.NppiBorderType.NPP_BORDER_UNDEFINED
# Finished crawling: https://docs.nvidia.com/cuda/cuda-quick-start-guide/index.html#redhat-centos
# Finished crawling: https://docs.nvidia.com/cuda/cuda-for-tegra-appnote/_images/cuDLA-create-device.png
# Finished crawling: https://docs.nvidia.com/cuda/cuda-runtime-api/structcudaChannelFormatDesc.html
# Finished crawling: https://docs.nvidia.com/cuda/cuda-runtime-api/deprecated.html#deprecated__deprecated_1_deprecated000023
# Finished crawling: https://docs.nvidia.com/cuda/cuda-driver-api/group__CUDA__EGL.html#group__CUDA__EGL_1g3ab15cff9be3b25447714101ecda6a61
# Finished crawling: https://docs.nvidia.com/cuda/cuda-driver-api/group__CUDA__GRAPH.html#group__CUDA__GRAPH_1gece6f3b9e85d0edb8484d625fe567376
# Finished crawling: https://docs.nvidia.com/cuda/cuda-runtime-api/structcudaGraphExecUpdateResultInfo.html
# Finished crawling: https://docs.nvidia.com/cuda/debugger-api/r_main.html#r_main
# Finished crawling: https://docs.nvidia.com/cuda/cuda-runtime-api/group__CUDART__TYPES.html#group__CUDART__TYPES_1gg0ec4aacc66fe76c145252d12b189e233b165b0917377d0d7283ca5ac8013568b
# Finished crawling: https://docs.nvidia.com/cuda/volta-tuning-guide/index.html#cuda-best-practices
# Finished crawling: https://docs.nvidia.com/cuda/cuda-quick-start-guide/index.html#debian
# Finished crawling: https://docs.nvidia.com/cuda/cufft/index.html#cuda-graphs-support
# Finished crawling: https://docs.nvidia.com/cuda/npp/signal_initialization.html#c.nppsZero_16sFinished crawling: https://docs.nvidia.com/cuda/wsl-user-guide/index.html#container-runtime-initialization-errors
#
# Finished crawling: https://docs.nvidia.com/cuda/ptx-writers-guide-to-interoperability/index.html#notices
# Finished crawling: https://docs.nvidia.com/cuda/npp/signal_initialization.html#c.nppsZero_64s_Ctx
# Finished crawling: https://docs.nvidia.com/cuda/cuda-runtime-api/group__CUDART__HIGHLEVEL.html#group__CUDART__HIGHLEVEL_1g99db510d18d37fbb0f5c075a8caf3b5f
# Finished crawling: https://docs.nvidia.com/cuda/npp/nppdefs.html#c.NppiPoint.y
# Finished crawling: https://docs.nvidia.com/cuda/cuda-runtime-api/group__CUDART__TYPES.html#group__CUDART__TYPES_1gabde707dfb8a602b917e0b177f77f365
# Finished crawling: https://docs.nvidia.com/cuda/cuda-driver-api/deprecated.html#deprecated__deprecated_1_deprecated000072
# Finished crawling: https://docs.nvidia.com/cuda/cuda-quick-start-guide/contents.html
# Finished crawling: https://docs.nvidia.com/cuda/cuda-driver-api/group__CUDA__TYPES.html#group__CUDA__TYPES_1ggc2cce590e35080745e72633dfc6e0b60b9f25a1b90274b624254eaaf836102fc
# Finished crawling: https://docs.nvidia.com/cuda/cuda-runtime-api/structcudaExternalSemaphoreSignalNodeParams.html#structcudaExternalSemaphoreSignalNodeParams_101b76e8f1ff0dd417d702001019767b2
# Finished crawling: https://docs.nvidia.com/cuda/cuda-runtime-api/deprecated.html#deprecated__deprecated_1_deprecated000020
# Finished crawling: https://docs.nvidia.com/cuda/cuda-runtime-api/group__CUDART__STREAM.html#group__CUDART__STREAM_1ge2be9e9858849bf62ba4a8b66d1c3540
# Finished crawling: https://docs.nvidia.com/cuda/volta-tuning-guide/index.html#high-bandwidth-memory
# Finished crawling: https://docs.nvidia.com/cuda/cuda-quick-start-guide/index.html#suse-linux-enterprise-server
# Finished crawling: https://docs.nvidia.com/cuda/npp/signal_initialization.html#c.nppsZero_64fc_Ctx
# Finished crawling: https://docs.nvidia.com/cuda/maxwell-tuning-guide/index.html#shared-memory-capacity
# Finished crawling: https://docs.nvidia.com/cuda/cuda-runtime-api/group__CUDART__OPENGL__DEPRECATED.html#group__CUDART__OPENGL__DEPRECATED_1gab71eaf2bf614b851e583ea27abb0ac1
# Finished crawling: https://docs.nvidia.com/cuda/cuda-runtime-api/group__CUDART__DEVICE.html#group__CUDART__DEVICE
# Finished crawling: https://docs.nvidia.com/cuda/npp/nppdefs.html#c.Npp64sc.re

# %%
import pandas as pd

# %%
df=pd.read_csv('nvidia_cuda_docs_info_1000_urls.csv')

# %%
df
# Out:
#                                         Topic Name  \
# 0      CUDA Toolkit Documentation 12.5 Update 1ï
# 1                           Installation Guidesï
# 2                            Programming Guidesï
# 3                           CUDA API Referencesï
# 4                   PTX Compiler API Referencesï
# ...                                            ...
# 31928             21.2.3.Multi-Node, Single-GPUï
# 31929                                22.Noticesï
# 31930                               22.1.Noticeï
# 31931                               22.2.OpenCLï
# 31932                           22.3.Trademarksï
#
#                                    Links  \
# 0      #cuda-toolkit-documentation-v12-4
# 1                   #installation-guides
# 2                    #programming-guides
# 3                   #cuda-api-references
# 4           #ptx-compiler-api-references
# ...                                  ...
# 31928             #multi-node-single-gpu
# 31929                           #notices
# 31930                            #notice
# 31931                            #opencl
# 31932                        #trademarks
#
#                                     Information and Text
# 0      CUDA Toolkit Documentation 12.5 Update 1ï De...
# 1                                 Installation Guidesï
# 2                                  Programming Guidesï
# 3                                 CUDA API Referencesï
# 4                         PTX Compiler API Referencesï
# ...                                                  ...
# 31928  21.2.3.Multi-Node, Single-GPUï Beyond memory...
# 31929                                      22.Noticesï
# 31930  22.1.Noticeï This document is provided for i...
# 31931  22.2.OpenCLï OpenCL is a trademark of Apple ...
# 31932  22.3.Trademarksï NVIDIA and the NVIDIA logo ...
#
# [31933 rows x 3 columns]

# %%
df=df.drop_duplicates()

# %%
df
# Out:
#                                         Topic Name  \
# 0      CUDA Toolkit Documentation 12.5 Update 1ï
# 1                           Installation Guidesï
# 2                            Programming Guidesï
# 3                           CUDA API Referencesï
# 4                   PTX Compiler API Referencesï
# ...                                            ...
# 31452             21.2.3.Multi-Node, Single-GPUï
# 31459                                22.Noticesï
# 31466                               22.1.Noticeï
# 31497                               22.2.OpenCLï
# 31504                           22.3.Trademarksï
#
#                                    Links  \
# 0      #cuda-toolkit-documentation-v12-4
# 1                   #installation-guides
# 2                    #programming-guides
# 3                   #cuda-api-references
# 4           #ptx-compiler-api-references
# ...                                  ...
# 31452             #multi-node-single-gpu
# 31459                           #notices
# 31466                            #notice
# 31497                            #opencl
# 31504                        #trademarks
#
#                                     Information and Text
# 0      CUDA Toolkit Documentation 12.5 Update 1ï De...
# 1                                 Installation Guidesï
# 2                                  Programming Guidesï
# 3                                 CUDA API Referencesï
# 4                         PTX Compiler API Referencesï
# ...                                                  ...
# 31452  21.2.3.Multi-Node, Single-GPUï Beyond memory...
# 31459                                      22.Noticesï
# 31466  22.1.Noticeï This document is provided for i...
# 31497  22.2.OpenCLï OpenCL is a trademark of Apple ...
# 31504  22.3.Trademarksï NVIDIA and the NVIDIA logo ...
#
# [3374 rows x 3 columns]

# %%
df['Topic Name'].value_counts()
# Out:
# Topic Name
# Search Results                                 398
# Variables                                      252
# Public Variables                               115
# Enumerations                                    82
# Functions                                       74
#                                               ...
# 10.15.Special Registers: %cluster_nctaidï      1
# 10.14.Special Registers: %cluster_ctaidï       1
# 10.13.Special Registers: %nclusteridï          1
# 10.12.Special Registers: %clusteridï           1
# 22.3.Trademarksï                               1
# Name: count, Length: 1937, dtype: int64

# %%
import string

# Printable characters
printable = set(string.printable)

# %%
 ## Function to remove non-printable characters
def remove_non_printable(s):
    return ''.join(filter(lambda x: x in printable, s))

# Apply the function to the "Topic Name" column
df["Topic Name"] = df["Topic Name"].apply(remove_non_printable)
# Out:
# <ipython-input-15-7cf64b438647>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Topic Name"] = df["Topic Name"].apply(remove_non_printable)

# %%
df['Information and Text']=df['Information and Text'].apply(remove_non_printable)
# Out:
# <ipython-input-19-a71309e21d8d>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Information and Text']=df['Information and Text'].apply(remove_non_printable)

# %%
df
# Out:
#                                      Topic Name  \
# 0      CUDA Toolkit Documentation 12.5 Update 1
# 1                           Installation Guides
# 2                            Programming Guides
# 3                           CUDA API References
# 4                   PTX Compiler API References
# ...                                         ...
# 31452             21.2.3.Multi-Node, Single-GPU
# 31459                                22.Notices
# 31466                               22.1.Notice
# 31497                               22.2.OpenCL
# 31504                           22.3.Trademarks
#
#                                    Links  \
# 0      #cuda-toolkit-documentation-v12-4
# 1                   #installation-guides
# 2                    #programming-guides
# 3                   #cuda-api-references
# 4           #ptx-compiler-api-references
# ...                                  ...
# 31452             #multi-node-single-gpu
# 31459                           #notices
# 31466                            #notice
# 31497                            #opencl
# 31504                        #trademarks
#
#                                     Information and Text
# 0      CUDA Toolkit Documentation 12.5 Update 1 Devel...
# 1                                    Installation Guides
# 2                                     Programming Guides
# 3                                    CUDA API References
# 4                            PTX Compiler API References
# ...                                                  ...
# 31452  21.2.3.Multi-Node, Single-GPU Beyond memory al...
# 31459                                         22.Notices
# 31466  22.1.Notice This document is provided for info...
# 31497  22.2.OpenCL OpenCL is a trademark of Apple Inc...
# 31504  22.3.Trademarks NVIDIA and the NVIDIA logo are...
#
# [3374 rows x 3 columns]

# %%
df['Topic Name']
# Out:
# 0        CUDA Toolkit Documentation 12.5 Update 1
# 1                             Installation Guides
# 2                              Programming Guides
# 3                             CUDA API References
# 4                     PTX Compiler API References
#                            ...
# 31452               21.2.3.Multi-Node, Single-GPU
# 31459                                  22.Notices
# 31466                                 22.1.Notice
# 31497                                 22.2.OpenCL
# 31504                             22.3.Trademarks
# Name: Topic Name, Length: 3374, dtype: object

# %%
 df.to_csv('clean_data.csv', index=False)

# %%
# Drop duplicates where both "Topic Name" and "Information and Text" are the same
df_cleaned = df.drop_duplicates(subset=["Topic Name", "Information and Text"])

# Display the cleaned DataFrame
df_cleaned
# Out:
#                                      Topic Name  \
# 0      CUDA Toolkit Documentation 12.5 Update 1
# 1                           Installation Guides
# 2                            Programming Guides
# 3                           CUDA API References
# 4                   PTX Compiler API References
# ...                                         ...
# 31452             21.2.3.Multi-Node, Single-GPU
# 31459                                22.Notices
# 31466                               22.1.Notice
# 31497                               22.2.OpenCL
# 31504                           22.3.Trademarks
#
#                                    Links  \
# 0      #cuda-toolkit-documentation-v12-4
# 1                   #installation-guides
# 2                    #programming-guides
# 3                   #cuda-api-references
# 4           #ptx-compiler-api-references
# ...                                  ...
# 31452             #multi-node-single-gpu
# 31459                           #notices
# 31466                            #notice
# 31497                            #opencl
# 31504                        #trademarks
#
#                                     Information and Text
# 0      CUDA Toolkit Documentation 12.5 Update 1 Devel...
# 1                                    Installation Guides
# 2                                     Programming Guides
# 3                                    CUDA API References
# 4                            PTX Compiler API References
# ...                                                  ...
# 31452  21.2.3.Multi-Node, Single-GPU Beyond memory al...
# 31459                                         22.Notices
# 31466  22.1.Notice This document is provided for info...
# 31497  22.2.OpenCL OpenCL is a trademark of Apple Inc...
# 31504  22.3.Trademarks NVIDIA and the NVIDIA logo are...
#
# [1968 rows x 3 columns]

# %%
df_cleaned.to_csv('clean_data_2.csv', index=False)

# %%
import pandas as pd

# %%
new_data=pd.read_csv('clean_data_2.csv')

# %%
new_data.columns
# Out:
# Index(['Topic Name', 'Links', 'Information and Text'], dtype='object')

# %%
# !pip install transformers
# !pip install torch
# !pip install milvus
# !pip install pymilvus
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.41.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.15.4)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.23.4)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2024.5.15)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.31.0)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.19.1)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.4)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.23.0->transformers) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.23.0->transformers) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2024.7.4)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (2.3.0+cu121)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch) (3.15.4)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch) (4.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch) (1.13.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch) (2023.6.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch)
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch)
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch)
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch)
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch)
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch)
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch)
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch)
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch)
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# Collecting nvidia-nccl-cu12==2.20.5 (from torch)
#   Using cached nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl (176.2 MB)
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch)
#   Using cached nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
# Requirement already satisfied: triton==2.3.0 in /usr/local/lib/python3.10/dist-packages (from torch) (2.3.0)
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch)
#   Downloading nvidia_nvjitlink_cu12-12.5.82-py3-none-manylinux2014_x86_64.whl (21.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.3/21.3 MB 53.1 MB/s eta 0:00:00
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch) (2.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch) (1.3.0)
# Installing collected packages: nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12
# Successfully installed nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.20.5 nvidia-nvjitlink-cu12-12.5.82 nvidia-nvtx-cu12-12.1.105
# Collecting milvus
#   Downloading milvus-2.3.5-py3-none-manylinux2014_x86_64.whl (57.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.7/57.7 MB 10.6 MB/s eta 0:00:00
# Installing collected packages: milvus
# Successfully installed milvus-2.3.5
# Collecting pymilvus
#   Downloading pymilvus-2.4.4-py3-none-any.whl (196 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 kB 5.2 MB/s eta 0:00:00
# Requirement already satisfied: setuptools>=67 in /usr/local/lib/python3.10/dist-packages (from pymilvus) (67.7.2)
# Collecting grpcio<=1.63.0,>=1.49.1 (from pymilvus)
#   Downloading grpcio-1.63.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 19.7 MB/s eta 0:00:00
# Requirement already satisfied: protobuf>=3.20.0 in /usr/local/lib/python3.10/dist-packages (from pymilvus) (3.20.3)
# Collecting environs<=9.5.0 (from pymilvus)
#   Downloading environs-9.5.0-py2.py3-none-any.whl (12 kB)
# Collecting ujson>=2.0.0 (from pymilvus)
#   Downloading ujson-5.10.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (53 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.6/53.6 kB 6.1 MB/s eta 0:00:00
# Requirement already satisfied: pandas>=1.2.4 in /usr/local/lib/python3.10/dist-packages (from pymilvus) (2.0.3)
# Collecting milvus-lite<2.5.0,>=2.4.0 (from pymilvus)
#   Downloading milvus_lite-2.4.8-py3-none-manylinux2014_x86_64.whl (49.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.4/49.4 MB 11.9 MB/s eta 0:00:00
# Collecting marshmallow>=3.0.0 (from environs<=9.5.0->pymilvus)
#   Downloading marshmallow-3.21.3-py3-none-any.whl (49 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.2/49.2 kB 6.1 MB/s eta 0:00:00
# Collecting python-dotenv (from environs<=9.5.0->pymilvus)
#   Downloading python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from milvus-lite<2.5.0,>=2.4.0->pymilvus) (4.66.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.2.4->pymilvus) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.2.4->pymilvus) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.2.4->pymilvus) (2024.1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.2.4->pymilvus) (1.25.2)
# Requirement already satisfied: packaging>=17.0 in /usr/local/lib/python3.10/dist-packages (from marshmallow>=3.0.0->environs<=9.5.0->pymilvus) (24.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas>=1.2.4->pymilvus) (1.16.0)
# Installing collected packages: ujson, python-dotenv, milvus-lite, marshmallow, grpcio, environs, pymilvus
#   Attempting uninstall: grpcio
#     Found existing installation: grpcio 1.64.1
#     Uninstalling grpcio-1.64.1:
#       Successfully uninstalled grpcio-1.64.1
# Successfully installed environs-9.5.0 grpcio-1.63.0 marshmallow-3.21.3 milvus-lite-2.4.8 pymilvus-2.4.4 python-dotenv-1.0.1 ujson-5.10.0

# %%
# !pip install sentence-transformers
# Out:
# Collecting sentence-transformers
#   Downloading sentence_transformers-3.0.1-py3-none-any.whl (227 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 227.1/227.1 kB 5.7 MB/s eta 0:00:00
# Requirement already satisfied: transformers<5.0.0,>=4.34.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (4.41.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (4.66.4)
# Requirement already satisfied: torch>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (2.3.0+cu121)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (1.25.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (1.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (1.11.4)
# Requirement already satisfied: huggingface-hub>=0.15.1 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (0.23.4)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (9.4.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence-transformers) (3.15.4)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence-transformers) (2023.6.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence-transformers) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence-transformers) (6.0.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence-transformers) (2.31.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence-transformers) (4.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (1.13.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (3.1.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (12.1.105)
# Requirement already satisfied: triton==2.3.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (2.3.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.10/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.11.0->sentence-transformers) (12.5.82)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.34.0->sentence-transformers) (2024.5.15)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.34.0->sentence-transformers) (0.19.1)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.34.0->sentence-transformers) (0.4.3)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->sentence-transformers) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->sentence-transformers) (3.5.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.11.0->sentence-transformers) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers) (2024.7.4)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.11.0->sentence-transformers) (1.3.0)
# Installing collected packages: sentence-transformers
# Successfully installed sentence-transformers-3.0.1

# %%
from sentence_transformers import SentenceTransformer
import numpy as np
from sklearn.cluster import KMeans
import pandas as pd

# Load the data
new_data= pd.read_csv('clean_data_2.csv')

# Load pre-trained SentenceTransformer model
model = SentenceTransformer('sentence-transformers/all-MiniLM-L6-v2')

# Generate embeddings for each text
embeddings = model.encode(new_data['Information and Text'].tolist())

# Cluster embeddings
num_clusters = 10
clustering_model = KMeans(n_clusters=num_clusters)
clustering_model.fit(embeddings)
cluster_assignment = clustering_model.labels_

# Add cluster assignments to data
new_data['Cluster'] = cluster_assignment
# Out:
# /usr/local/lib/python3.10/dist-packages/sentence_transformers/cross_encoder/CrossEncoder.py:11: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm, trange
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.7k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
new_data.columns
# Out:
# Index(['Topic Name', 'Links', 'Information and Text', 'Cluster'], dtype='object')

# %%
# Function to lowercase and remove hashtags
def clean_text(text):
    # Lowercase the text
    text = text.lower()
    # Remove hashtags
    text = text.replace("#", "")
    return text

# Apply the function to the 'Topic Name' and 'Information and Text' columns
new_data['Topic Name'] = new_data['Topic Name'].apply(clean_text)
new_data['Information and Text'] = new_data['Information and Text'].apply(clean_text)

# %%
new_data = new_data.drop_duplicates(subset=["Topic Name", "Information and Text"])

# %%
new_data.to_csv('clustered_data_2.csv', index=False)
